# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmavishal94/python/blob/main/Beginner_03__Control_Structure_(Loops).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A.
#
# Take Input from a User and perform the following actions.
#
# - If  is odd, print Weird
# - If  is even and in the inclusive range of  to , print Not Weird
# - If  is even and in the inclusive range of  to , print Weird
# - If  is even and greater than , print Not Weird
#
# > Sample Input : 3, Output: Weird
#
# > Sample Input : 24, Output : Not Weird

# %% [markdown]
# # 1. Why you I should Learn Loops ? 🚀

# %% [markdown]
# > **Fundamental Programming Constructs.**
# - Enable the repetition of a block of code. ( Automate Tasks/Analyze Data) etc.
# - Magical shortcut : Turn repetitive, boring tasks into elegant, automated solutions
# - This repetition is crucial for various tasks.
#
# ### Sales
# 1.  Automating follow-up emails to leads.
# 2.  Summing up total sales from different regions.
#
# ### Service
#
# 1. Iterating through Case Comments to generate Case Summaries.
# 2. Calcuate TTR for all Cases.
#
# ### Marketing
# 1. Iterating over a list of campaign IDs to fetch performance data
# 2. Sending discount codes to a list of customers.

# %% [markdown]
# ## Learn Python Loops
#
# #### <b>What are Python Loops?</b>
# If you need to do something 100 times, you certainly don't need to write it out in 100 identical lines of code.
#
# In Python, loops allow you to iterate over a sequence, whether that's a list, tuple, string, or dictionary.
#
# A loop allows you to repeat actions without rewriting the same code.
#
# #### <b>What types of Python Loops are there?</b>
# There is a <b>for</b> loop and a <b>while</b> loop.
# For Loop: Used when you know how many times you want to iterate.
# While Loop: Used when the number of iterations depends on a condition.
#
# #### <b>The for statement</b>
#
# A "for" loop in Python allows you to go through each item in a sequence, one at a time. This allows you to "iterate" through an "iterable", such as a Python list, and perform operations on each item one at a time.
#
# The simplest example is to step through the items in a list:

# %% [markdown]
# # 2. Key Components of Loops
# Since I have decided to learn loops , there is no going back

# %% [markdown]
# For Loop Structure:

# %%
for item in iterable:
    # Do something

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
maruthi_org = ["Eric", "Susanna", "Mohit","Suchi"]
for member in maruthi_org:
    print(member)

# %% [markdown]
# While Loop Structure:

# %%
while condition:
    # Do something

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
count = 5
while count > 0:
    print(count)
    count = count - 1

# %% [markdown]
# Example 1: Calculate the total of numbers in a list.

# %%
numbers = [1, 2, 3, 4, 5]
total = 0
for num in numbers:
    total += num  #
print("Total:", total)

# %% [markdown]
# Example 2: Print "Hello" five times.

# %%
for i in range(5):
    print("Hello")

# %%
my_fruits = ['apple', 'banana', 'cherry']
for fruit in my_fruits:
    print(fruit)

# %% [markdown]
# #### <b>The range() function</b>
# In most cases, we will want to loop through a predetermined list. However, we can also generate a list to loop over "on the fly" with the <b>range()</b> function.

# %%
for i in range(8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# You can use the <b>range()</b> function together with the <b>len()</b> function to loop through a list, along with a variable that has the current index in the sequence.

# %%
my_list = [10, 20, 30, 40, 50, 60]

for i in range(len(my_list)):
    print(i, my_list[i])
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60

# %% [markdown]
# #### <b>Enumerate</b>
# You can achieve the same effect as above by using the enumerate() function, to get two values each step through the loop.

# %%
# the enumerate function will return two values each time the loop statement is run:
# "indx" will be the current index value, and "val" will be the current element of my_list
for indx, val in enumerate(my_list):
    print(indx, val)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
# 5 60

# %% [markdown]
# #### <b>Loop through the characters in a string</b>
# You can also loop through all characters in a string of text in order.

# %%
s = "Once Upon a Time in Mumbaai"
for `?` in s:
    print(character)

# %% [markdown]
# #### <b>Looping through a dictionary</b>
# #### keys()
# You can step through the keys of a dictionary.

# %%
my_dict = {'AAPL': 100, 'MSFT': 200, 'GOOG': 300, 'CSCO': 400}

for key in my_dict.keys():
    print(?)

# %% [markdown]
# #### items() -> https://docs.python.org/3/tutorial/datastructures.html#dictionaries
#
# https://docs.python.org/3/library/stdtypes.html#dict-views
#
# - Alternatively, you can step through all the items in the dictionary.
# - Each item is a key-value pair.

# %%
my_dict = {'AAPL': 100, 'MSFT': 200, 'GOOG': 300, 'CSCO': 400}

for key, value in my_dict.items():
    print('Key= ' + key + ', Value= ' + str(?))

# %% [markdown]
# ## Example Loops
#
# <b>1 - Count the number of even elements in a list </b>
#
# Loop through my_list_1 and keep a counter of all the even numbers in the list. The code below shows how to do this using a For Loop and List Comprehension.

# %%
my_list_1 = [252, 9, 258, 220, 249, 83, 195, 298, 228, 67, 233, 133, 280, 96, 53, 204,
            247, 268, 115, 127, 215, 214, 221, 275, 224, 36, 292, 145, 150, 17, 93,
            292, 206, 229, 189, 41, 246, 279, 158, 161, 90, 47, 195, 137, 171, 5,
            206, 106, 58, 226, 140, 6, 29, 277, 192, 47, 296, 90, 19, 290, 235, 229,
            26, 8, 220, 168, 294, 238, 138, 150, 13, 143, 209, 102, 192, 2, 140, 6, 99, 189
            ]

# %%
#Using a for loop
counter = 0
for elt in my_list_1:
    if elt % ? == 0:
        counter = counter + 1
counter
# Out:
# 42

# %% [markdown]
# <b>2 - Find Stocks with PE Ratio in a certain range </b>
#
# Using the code below, you start with a dictionary of stocks and come up with a list of stocks that have a PE ratio between 10 and 15.

# %%
my_dict_pe={'AXP':9,'VZ':10.2,'BA':None,'CAT':8.3,'JPM':7.9,
            'CVX':9.3,'KO':17.9,'DIS':19.1,'MRK':13.7,'MMM':13.3}

#code for list of PE stocks in range
screened_stocks=[] # filtered Stock
for item in my_dict_pe.items():
    key,val = item
    if val is not None and val>=10 and val <=15:
        screened_stocks.append(key)
print(screened_stocks)
# Out:
# ['VZ', 'MRK', 'MMM']

# %% [markdown]
# <b>3 - Calculate the Market Value on a Portfolio ( Calculation within the Loop) </b>
#
# Loop through the shares list and calculate the position value, multiplying number of shares by the price.

# %%
shares = [8000, 3500, 14100, 2100, 1500, 7500, 4800, 2800, 3700, 8200, 900, 1300, 6200, 16200, 500, 2900, 5100, 5000, 10700, 1000, 1100, 16900, 800, 200, 2900, 1700, 500, 800]
prices = [60.02, 148.85, 37.76, 213.99, 193.59, 53.85, 123.21, 118.72, 116.74, 68.3, 113.39, 117.23, 130.4, 32.96, 134.45, 86.75, 139.33, 87.58, 38.19, 354.67, 141.34, 11.08, 309.89, 306.56, 19.93, 132.65, 92.92, 46.4]

### Your code here
position_values=[]
for i in range(len(shares)):
    position_values.append(shares[?] * prices[?])

print('Position Values: ', position_values)
print('Total Portfolio Value: ', sum(position_values))

# %% [markdown]
# # While VS For Loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Both loops can achieve the same results in some scenarios, but choosing the appropriate loop improves code clarity and readability.

# %% [markdown]
# # Homework

# %% [markdown]
# Print each Element of List & length of each element.
#
#
# ```
# # words = ['cat', 'window', 'defenestrate']
#
# cat 3
# ```

# %% [markdown]
# ##  1: Solve below problem using for for and while loop
#
# - Print the numbers from 1 to 10 (inclusive).
# - Print the square of each number alongside it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Loop Control Statement ( Break & Continue)

# %% [markdown]
# 1. Using break in a Loop
# The break statement is used to exit a loop prematurely when a certain condition is met.

# %%
# Finding the First Even Number in a List

numbers = [1, 3, 5, 6, 7, 9]

for num in numbers:
    if num % 2 == 0:
        print(f"First even number found: {num}")
        break
print("End of loop.")
# Out:
# First even number found: 6
# End of loop.

# %% [markdown]
# Explanation: The loop stops as soon as it finds the first even number.

# %% [markdown]
# 2. Using continue in a Loop.
# - The continue statement skips the rest of the code inside the loop for the current iteration and moves to the next iteration.

# %%
# Skipping Odd Numbers
numbers = [1, 2, 3, 4, 5]

for num in numbers:
    if num % 2 != 0:
        continue  # Skip odd numbers
    print(f"Even number: {num}")

# %% [markdown]
# Homework 2: In the below list, I want to Skip numbers that are divisible by 5 and less than 25 but, if the number is greater than 25 I want to print that number.
#
# Use Loops

# %%
# numbers = [10, 15, 20, 25, 30]

# %% [markdown]
# HW - 3
# 1. Take a number as input from a user.
# 2. Print the square of each number starting from 0
#
# Example : 4
# - 0
# - 1
# - 4
# - 9

# %% [markdown]
# # Use of Loop in AI/ML

# %% [markdown]
# ### Machine Learning:
#
# 1. Model Training:
# Iteratively updating model parameters using optimization algorithms (e.g., gradient descent) to minimize the loss function.
# Batching data to improve training efficiency.
# 2. Model Prediction:
# Iterating over input data to generate predictions.
# 3. Model Deployment:
# Deploying models to production environments and continuously monitoring their performance.

# %% [markdown]
# ### Data Science
#
# 1. Data Cleaning and Preprocessing:
# - Iterating over datasets to identify and handle missing values, outliers, and inconsistencies.
# - Normalizing or standardizing features to ensure consistent scales.
# Transforming categorical variables into numerical representations (e.g., one-hot encoding).
# 2. Exploratory Data Analysis (EDA):
# - Calculating summary statistics (mean, median, mode, standard deviation) for each feature.
# - Visualizing data distributions through histograms, box plots, and scatter plots.
# - Identifying correlations between variables using correlation matrices or heatmaps.
# 3. Feature Engineering:
# - Creating new features by combining existing ones (e.g., interaction terms).
# - Transforming features to improve model performance (e.g., polynomial features).
# 4. Model Evaluation:
# 1. Iterating over different hyperparameter settings to find the optimal configuration.
# 2. Cross-validating models to assess their generalization performance.
# 3. Calculating performance metrics (e.g., accuracy, precision, recall, F1-score) on test data.
